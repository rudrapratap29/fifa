# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import seaborn as sb

# %%
netflix = pd.read_csv("/content/netflix_titles.csv")
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix.shape
# Out:
# (8807, 12)

# %%
netflix.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
netflix.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
netflix.size
# Out:
# 105684

# %%
netflix.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
netflix.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
netflix[netflix.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
netflix.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
netflix.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
sb.heatmap(netflix.isnull())
# Out:
# <Axes: >

# %%
netflix['title']
# Out:
# 0        Dick Johnson Is Dead
# 1               Blood & Water
# 2                   Ganglands
# 3       Jailbirds New Orleans
# 4                Kota Factory
#                 ...
# 8802                   Zodiac
# 8803              Zombie Dumb
# 8804               Zombieland
# 8805                     Zoom
# 8806                   Zubaan
# Name: title, Length: 8807, dtype: object

# %%
netflix[netflix['title'].isin(['House of Cards'])]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %%
netflix[netflix['title'].str.contains('House of Cards')]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %%
netflix['data_y'] = pd.to_datetime(netflix['release_year'])

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
netflix['data_y'].dt.year.value_counts()
# Out:
# 1970    8807
# Name: data_y, dtype: int64

# %%
netflix['data_y'].dt.year.value_counts().plot(kind = 'bar', xlabel ='year' , ylabel = 'total number of movies and shows',width = 0.1)
# Out:
# <Axes: xlabel='year', ylabel='total number of movies and shows'>

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
netflix.groupby('country').country.count()
# Out:
# country
# , France, Algeria                                       1
# , South Korea                                           1
# Argentina                                              56
# Argentina, Brazil, France, Poland, Germany, Denmark     1
# Argentina, Chile                                        2
#                                                        ..
# Venezuela                                               1
# Venezuela, Colombia                                     1
# Vietnam                                                 7
# West Germany                                            1
# Zimbabwe                                                1
# Name: country, Length: 748, dtype: int64

# %%
plt.bar(netflix.groupby('country').country.count(),height = 8)
# Out:
# <BarContainer object of 748 artists>

# %%
sb.countplot(netflix['title'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-925deffbec7e> in <cell line: 1>()
# ----> 1 sb.countplot(netflix['title'])
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2941         raise ValueError("Cannot pass values for both `x` and `y`")
#    2942
# -> 2943     plotter = _CountPlotter(
#    2944         x, y, hue, data, order, hue_order,
#    2945         estimator, errorbar, n_boot, units, seed,
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1528                  errcolor, errwidth, capsize, dodge):
# ...

# %%
netflix['yearr']  = netflix['data_y'].dt.year

# %%
netflix.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
#
#                          data_y  yearr
# 0 1970-01-01 00:00:00.000002020   1970
# ...

# %%
netflix[(netflix['type'] == 'Movie') & (netflix['yearr'] == 1970)].head(2)
# Out:
#   show_id   type                             title  \
# 0      s1  Movie              Dick Johnson Is Dead
# 6      s7  Movie  My Little Pony: A New Generation
#
#                         director  \
# 0                Kirsten Johnson
# 6  Robert Cullen, José Luis Ucha
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...            NaN
#
#            date_added  release_year rating duration                 listed_in  \
# 0  September 25, 2021          2020  PG-13   90 min             Documentaries
# 6  September 24, 2021          2021     PG   91 min  Children & Family Movies
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
# 6  Equestria's divided. But a bright-eyed hero be...
#
#                          data_y  yearr
# 0 1970-01-01 00:00:00.000002020   1970
# ...

# %%
plt.bar(netflix['type'] == 'Movie',netflix['yearr'] == 1970,width = 0.1,color = ['hotpink','blue'])
# Out:
# <BarContainer object of 8807 artists>

# %%
datanew = netflix.dropna()
datanew
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
datanew[datanew['cast'].str.contains('Vicky Kaushal')]
# Out:
#      show_id   type                 title  \
# 1678   s1679  Movie      Raman Raghav 2.0
# 4507   s4508  Movie                 Sanju
# 4825   s4826  Movie          Lust Stories
# 5040   s5041  Movie  Love Per Square Foot
# 8806   s8807  Movie                Zubaan
#
#                                                director  \
# 1678                                     Anurag Kashyap
# 4507                                    Rajkumar Hirani
# 4825  Zoya Akhtar, Karan Johar, Anurag Kashyap, Diba...
# 5040                                       Anand Tiwari
# 8806                                        Mozez Singh
#
#                                                    cast country  \
# 1678  Nawazuddin Siddiqui, Vicky Kaushal, Sobhita Dh...   India
# 4507  Ranbir Kapoor, Vicky Kaushal, Paresh Rawal, So...   India
# 4825  Vicky Kaushal, Bhumi Pednekar, Radhika Apte, N...   India
# 5040  Vicky Kaushal, Angira Dhar, Alankrita Sahai, R...   India
# ...

# %%
datanew['rating'].nunique()

# %%
datanew['rating'].unique()
# Out:
# array(['TV-MA', 'TV-14', 'PG-13', 'PG', 'R', 'TV-PG', 'G', 'TV-Y7',
#        'TV-G', 'TV-Y', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
datanew[(datanew['type'] == 'Movie') & (datanew['rating'] == 'TV-MA') & (datanew['country']== 'India')].head()
# Out:
#     show_id   type                      title          director  \
# 202    s203  Movie          Kyaa Kool Hai Hum    Sangeeth Sivan
# 203    s204  Movie       Kyaa Kool Hain Hum 3      Umesh Ghadge
# 204    s205  Movie   Kyaa Super Kool Hain Hum      Sachin Yardi
# 206    s207  Movie  LSD: Love, Sex Aur Dhokha  Dibakar Banerjee
# 210    s211  Movie                 Ragini MMS   Pawan Kripalani
#
#                                                   cast country  \
# 202  Tusshar Kapoor, Riteish Deshmukh, Isha Koppika...   India
# 203  Tusshar Kapoor, Aftab Shivdasani, Krishna Abhi...   India
# 204  Tusshar Kapoor, Riteish Deshmukh, Anupam Kher,...   India
# 206  Nushrat Bharucha, Anshuman Jha, Neha Chauhan, ...   India
# 210  Kainaz Motivala, Rajkummar Rao, Rajat Kaul, Ja...   India
#
#           date_added  release_year rating duration  \
# 202  August 27, 2021          2005  TV-MA  165 min
# 203  August 27, 2021          2016  TV-MA  124 min
# ...

# %%
datanew['duration'].unique()
# Out:
# array(['125 min', '9 Seasons', '104 min', '127 min', '166 min', '103 min',
#        '97 min', '106 min', '96 min', '124 min', '116 min', '98 min',
#        '91 min', '115 min', '122 min', '99 min', '88 min', '100 min',
#        '102 min', '93 min', '95 min', '85 min', '83 min', '182 min',
#        '147 min', '90 min', '128 min', '143 min', '119 min', '114 min',
#        '118 min', '108 min', '117 min', '121 min', '142 min', '113 min',
#        '154 min', '120 min', '82 min', '94 min', '109 min', '101 min',
#        '105 min', '86 min', '229 min', '76 min', '89 min', '110 min',
#        '156 min', '112 min', '129 min', '107 min', '1 Season', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '145 min', '92 min',
#        '2 Seasons', '64 min', '59 min', '111 min', '87 min', '148 min',
#        '189 min', '141 min', '130 min', '7 Seasons', '68 min', '131 min',
#        '126 min', '155 min', '123 min', '84 min', '4 Seasons', '13 min',
# ...

# %%
datanew['duration'].max()
# Out:
# '99 min'

# %%
tv_show = datanew[datanew['type'] == 'Movie']
tv_show.head()
# Out:
#    show_id   type         title             director  \
# 7       s8  Movie       Sankofa         Haile Gerima
# 9      s10  Movie  The Starling       Theodore Melfi
# 12     s13  Movie  Je Suis Karl  Christian Schwochow
# 24     s25  Movie         Jeans           S. Shankar
# 27     s28  Movie     Grown Ups         Dennis Dugan
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# 27  Adam Sandler, Kevin James, Chris Rock, David S...
#
#                                               country          date_added  \
# 7   United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 9                                       United States  September 24, 2021
# 12                            Germany, Czech Republic  September 23, 2021
# ...

# %%
tv_show.country.value_counts().head()
# Out:
# United States     1819
# India              868
# United Kingdom     164
# Canada             104
# Egypt               90
# Name: country, dtype: int64

# %%
datanew.sort_values(by='yearr').head(2)
# Out:
#      show_id   type            title      director  \
# 7         s8  Movie          Sankofa  Haile Gerima
# 6280   s6281  Movie  Below Her Mouth  April Mullen
#
#                                                    cast  \
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 6280  Erika Linder, Natalie Krill, Sebastian Pigott,...
#
#                                                 country          date_added  \
# 7     United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 6280                                             Canada      August 1, 2017
#
#       release_year rating duration  \
# 7             1993  TV-MA  125 min
# 6280          2016  TV-MA   91 min
#
#                                              listed_in  \
# 7     Dramas, Independent Movies, International Movies
# 6280  Dramas, Independent Movies, International Movies
#
#                                             description  \
# 7     On a photo shoot in Ghana, an American model s...
# ...

# %%
datanew[(datanew['director'] == 'April Mullen') & (datanew['country'] == 'Canada') | (datanew['rating'] == 'TV-MA')]
# Out:
#      show_id   type                   title                    director  \
# 7         s8  Movie                 Sankofa                Haile Gerima
# 12       s13  Movie            Je Suis Karl         Christian Schwochow
# 73       s74  Movie            King of Boys                Kemi Adetiba
# 84       s85  Movie    Omo Ghetto: the Saga  JJC Skillz, Funke Akindele
# 90       s91  Movie          Paradise Hills            Alice Waddington
# ...      ...    ...                     ...                         ...
# 8762   s8763  Movie         Wrong Side Raju               Mikhil Musale
# 8769   s8770  Movie  Y.M.I.: Yeh Mera India                  N. Chandra
# 8788   s8789  Movie            You Carry Me                  Ivona Juka
# 8798   s8799  Movie                Zed Plus     Chandra Prakash Dwivedi
# 8801   s8802  Movie                 Zinzana             Majid Al Ansari
#
#                                                    cast  \
# ...

# %%
plt.bar(datanew[(datanew['type'] == 'TV-Show')],datanew[(datanew['type'] == 'Kids-TV')])
# Out:
# <BarContainer object of 0 artists>
